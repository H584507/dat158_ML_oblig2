# %%
from pycaret.regression import load_model, predict_model
import pandas as pd
import numpy as np
import streamlit as st
from PIL import Image
import os
# Out:
# ---------------------------------------------------------------------------
# ContextualVersionConflict                 Traceback (most recent call last)
# <ipython-input-25-18f7bc279b9f> in <module>
#       2 import pandas as pd
#       3 import numpy as np
# ----> 4 import streamlit as st
#       5 from PIL import Image
#       6 import os
#
# D:\anaconda3\envs\dat158\lib\site-packages\streamlit\__init__.py in <module>
#      58 # This used to be pkg_resources.require('streamlit') but it would cause
#      59 # pex files to fail. See #394 for more details.
# ---> 60 __version__ = _pkg_resources.get_distribution("streamlit").version
#      61
#      62 import contextlib as _contextlib
#
# D:\anaconda3\envs\dat158\lib\site-packages\pkg_resources\__init__.py in get_distribution(dist)
#     464         dist = Requirement.parse(dist)
#     465     if isinstance(dist, Requirement):
# --> 466         dist = get_provider(dist)
#     467     if not isinstance(dist, Distribution):
# ...

# %%
class StreamlitApp:
    
    def __init__(self):
        self.model = load_model('final_model_house_values') 
        self.save_fn = 'path.csv'     
        
    def predict(self, input_data): 
        return predict_model(self.model, data=input_data)

    def store_prediction(self, output_df): 
        if os.path.exists(self.save_fn):
            save_df = pd.read_csv(self.save_fn)
            save_df = save_df.append(output_df, ignore_index=True)
            save_df.to_csv(self.save_fn, index=False)
            
        else: 
            output_df.to_csv(self.save_fn, index=False)  
            
    
    def run(self):
        image = Image.open('/data/house.jpg')
        st.image(image, use_column_width=False)
    
    
        add_selectbox = st.sidebar.selectbox('How would you like to predict?', ('Online', 'Batch')) #bruke batch for aa predikere paa alle bildene. 
        st.sidebar.info('This app predicts the value of a house' )
        st.sidebar.success('DAT158')
        st.title('House value prediction')
        
       
        if add_selectbox == 'Online': 
            
            #Placeholder fields 
            mssubclass = st.selectbox('Dwelling type', [20, 30, 40, 45, 50, 60, 70, 
                                                        75,80,85,90,120,150,160,180,190])
            mszoning = st.selectbox('MSZoning',['A','C','FV','I','RH','RL','RP','RM'])
            lotfrontage = st.selectbox('', [])
            lotare = st.selectbox('', [])
            stree = st.selectbox('', [])
            alley = st.selectbox('', [])
            lotshape = st.selectbox('', [])
            utilities = st.selectbox('', [])
            lotconfig = st.selectbox('', [])
            landslope = st.selectbox('', [])
            neighborhood = st.selectbox('', [])
            condition1 = st.selectbox('', [])
            condition2 = st.selectbox('', [])
            bldgtype = st.selectbox('', [])
            housestyle = st.selectbox('', [])
            overallqual = st.selectbox('', [])
            overallcond = st.selectbox('', [])
            yearbuilt = st.selectbox('', [])
            yearremodadd = st.selectbox('', [])
            roofstyle = st.selectbox('', [])
            roofmatl = st.selectbox('', [])
            exterior1st = st.selectbox('', [])
            exterior2nd = st.selectbox('', [])
            masvnrtype = st.selectbox('', [])
            masvnrarea = st.selectbox('', [])
            exterqual = st.selectbox('', [])
            extercond = st.selectbox('', [])
            foundation = st.selectbox('', [])
            bsmtqual = st.selectbox('', [])
            bsmtcond = st.selectbox('', [])
            bsmtexposure = st.selectbox('', [])
            bsmtfintype1 = st.selectbox('', [])
            bsmtfinsf1 = st.selectbox('', [])
            bsmtfintype2 = st.selectbox('', [])
            bsmtfinsf2 = st.selectbox('', [])
            totalbsmtsf = st.selectbox('', [])
            heating = st.selectbox('', [])
            heatingqc = st.selectbox('', [])
            centralair = st.selectbox('', [])
            electrical = st.selectbox('', [])
            _1stflrsf= st.selectbox('', [])
            _2ndflrsf= st.selectbox('', [])
            lowqualfinsf = st.selectbox('', [])
            grlivarea = st.selectbox('', [])
            bsmtfullbath = st.selectbox('', [])
            bsmthalfbath= st.selectbox('', [])
            fullbath = st.selectbox('', [])
            halfbath = st.selectbox('', [])
            bedroom = st.selectbox('', [])
            kitchen = st.selectbox('', [])
            kitchenqual = st.selectbox('', [])
            totrmsabvgrd = st.selectbox('', [])
            functional = st.selectbox('', [])
            fireplaces = st.selectbox('', [])
            fireplacequ = st.selectbox('', [])
            fireplacebsmt = st.selectbox('', [])
            garagetype = st.selectbox('', [])
            garageyrblt = st.selectbox('', []) 
            garagefinish = st.selectbox('', [])
            garagecars  = st.selectbox('', [])
            garagearea  = st.selectbox('', [])
            garagequal = st.selectbox('', [])
            garagecond  = st.selectbox('', [])
            paveddrive = st.selectbox('', [])
            wooddecksf = st.selectbox('', [])
            openporchsf = st.selectbox('', [])
            _3ssnporch = st.selectbox('', [])
            screenporch = st.selectbox('', [])
            poolarea = st.selectbox('', [])
            poolqc = st.selectbox('', [])
            fence = st.selectbox('', [])
            miscfeature = st.selectbox('', [])
            miscval = st.selectbox('', [])
            mosold = st.selectbox('', [])
            yrsold  = st.slider(label, min_value=1900, max_value=2021, value=1950, step=1)
            saletype = st.selectbox('', [])
            salecondition = st.selectbox('', [])
            
#             age = st.number_input('Age', min_value=18, max_value=100, value=25) #remember trained on age between ...
#             sex = st.selectbox('Sex', ['M', 'F'])
#             chest_pain_type = st.selectbox('ChestPainType', ['ASY', 'NAP', 'ATA', 'TA'])
#             resting_bp = st.number_input('RestingBP', min_value=0, max_value=210, value=60)
#             cholesterol = st.number_input('Cholesterol', min_value=0, max_value=605, value=200)            
#             resting_ECG = st.selectbox('RestingECG', ['Normal', 'LVH', 'ST'])
#             max_hr = st.number_input('MaxHR', min_value=0, max_value=210, value=140)
#             oldpeak = st.slider('Oldpeak',min_value=0.0, max_value=7.0, value=1.0, step=0.1)  
#             st_slope = st.selectbox('ST_Slope', ['Flat', 'Up', 'Down'])
            
            
#             fasting_bs, exercise_angina= False, False
#             if st.checkbox('FastingBS'): fasting_bs=True

#             if st.checkbox('ExerciseAngina'): exercise_angina=True
            

            
#             output=''
#             input_dict = {'Age':age, 'Sex':sex, 'ChestPainType':chest_pain_type, 'RestingBP':resting_bp, 'Cholesterol':cholesterol, 'is_FastingBS':fasting_bs, 
#                           'RestingECG':resting_ECG, 'MaxHR':max_hr, 'is_ExerciseAngina':exercise_angina, 'Oldpeak':oldpeak, 'ST_Slope':st_slope}
#             input_df = pd.DataFrame(input_dict, index=[0])
            input_dict = {'MSZoning':MSZoning}
    
            if st.button('Predict'): 
                output = self.predict(input_df)
                self.store_prediction(output)
                
                output = 'House value ' + str(output['Label'])
                #if output['Label'][0] == 1 else 'Normal'
                #output = str(output['Label'])
                
            
            st.success('Predicted output: {}'.format(output))
            
        if add_selectbox == 'Batch': 
            fn = st.file_uploader("Upload csv file for predictions") #st.file_uploader('Upload csv file for predictions, type=["csv"]')
            if fn is not None: 
                input_df = pd.read_csv(fn)
                predictions = self.predict(input_df)
                st.write(predictions)
            
sa = StreamlitApp()
sa.run()

# %%
# !jupyter nbconvert --to script streamlitapp.ipynb
